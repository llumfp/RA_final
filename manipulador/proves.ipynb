# %%
from poses import CONFIGURACIONS

with open('output_movement.txt', 'r') as file:
    a = file.readlines()
moves = a[-58:-10]

moves_clean = []
for m in moves:
    m = m.replace('step','').replace('  ','').replace('\n','').split(':')[1][1:].split()
    moves_clean.append(m)


for step in moves_clean:
    if step[0] == 'MOVER':
        init = CONFIGURACIONS[step[-2]]
        final = CONFIGURACIONS[step[-1]]

    elif step[0] == 'PLACE':
        pos = CONFIGURACIONS[step[-2]]
        nivell = CONFIGURACIONS[step[-1]]
    
    elif step[0] == 'PICK':
        pos = CONFIGURACIONS[step[-1]]


print(moves_clean)
# Out:
# [-121.83, -96.79, -110.78, -62.65, 91.92, 147.28]
# [-79, -180.1, 44.61, -135.9, 88.42, 188.4]
# [-79, -180.1, 44.61, -135.9, 88.42, 188.4]
# [-62.12, 112.84, -88.22, -69.94, 88.64, 206.73]
# [-62.12, 112.84, -88.22, -69.94, 88.64, 206.73]
# [-67.94, -135.31, -51.58, -81.86, 89.73, 202.52]
# [-67.94, -135.31, -51.58, -81.86, 89.73, 202.52]
# [-111, -110, -92.19, -68.15, 89.79, 156.98]
# [-111, -110, -92.19, -68.15, 89.79, 156.98]
# [-103.86, -173.52, 24, -114.17, 93.06, 162.91]
# [-103.86, -173.52, 24, -114.17, 93.06, 162.91]
# [-67.87, -60.47, -136.57, -74.48, 89.67, 199.76]
# [-67.87, -60.47, -136.57, -74.48, 89.67, 199.76]
# [-77.88, -114.82, -84.69, -72.79, 90.12, 189.35]
# [-77.88, -114.82, -84.69, -72.79, 90.12, 189.35]
# [-62.12, 112.84, -88.22, -69.94, 88.64, 206.73]
# [-62.12, 112.84, -88.22, -69.94, 88.64, 206.73]
# [-91.27, -117.11, -82.6, -69.32, 87.54, 174.56]
# [-91.27, -117.11, -82.6, -69.32, 87.54, 174.56]
# [-62.12, 112.84, -88.22, -69.94, 88.64, 206.73]
# [-62.12, 112.84, -88.22, -69.94, 88.64, 206.73]
# [-106.28, -128.59, -63.37, -77.7, 90.5, 160.19]
# [-106.28, -128.59, -63.37, -77.7, 90.5, 160.19]
# [-111, -110, -92.19, -68.15, 89.79, 156.98]
# [-111, -110, -92.19, -68.15, 89.79, 156.98]
# [-53.52, -89.15, -117.68, -63.64, 88.4, 212.63]
# [-53.52, -89.15, -117.68, -63.64, 88.4, 212.63]
# [-111, -110, -92.19, -68.15, 89.79, 156.98]
# [-111, -110, -92.19, -68.15, 89.79, 156.98]
# [-75.1, -91.54, -115.2, -63.73, 90.07, 192.97]
# [-75.1, -91.54, -115.2, -63.73, 90.07, 192.97]
# [-67.87, -60.47, -136.57, -74.48, 89.67, 199.76]
# [-67.87, -60.47, -136.57, -74.48, 89.67, 199.76]
# [-94.52, -98.17, -107.87, -64.43, 89.91, 173.46]
# [-94.52, -98.17, -107.87, -64.43, 89.91, 173.46]
# [-67.87, -60.47, -136.57, -74.48, 89.67, 199.76]
# [-67.87, -60.47, -136.57, -74.48, 89.67, 199.76]
# [-121.83, -96.79, -110.78, -62.65, 91.92, 147.28]
# [-121.83, -96.79, -110.78, -62.65, 91.92, 147.28]
# [-91, -178.24, 38.1, -127.98, 88.32, 178.5]
# [-91, -178.24, 38.1, -127.98, 88.32, 178.5]
# [-38.68, -63.72, -134.57, -75.23, 90.58, 228.28]
# [-38.68, -63.72, -134.57, -75.23, 90.58, 228.28]
# [-91, -178.24, 38.1, -127.98, 88.32, 178.5]
# [-91, -178.24, 38.1, -127.98, 88.32, 178.5]
# [-97.74, -72.63, -134.52, -60.22, 90.36, 168.99]
# [-97.74, -72.63, -134.52, -60.22, 90.36, 168.99]
# [-91, -178.24, 38.1, -127.98, 88.32, 178.5]
# [['MOVER', 'ROB', 'POS1', 'POS15'], ['PICK', 'ROB', 'P15', 'POS15'], ['MOVER', 'ROB', 'POS15', 'POS12'], ['PLACE', 'ROB', 'P15', 'POS12', 'H1'], ['MOVER', 'ROB', 'POS12', 'POS16'], ['PICK', 'ROB', 'P16', 'POS16'], ['MOVER', 'ROB', 'POS16', 'POS5'], ['PLACE', 'ROB', 'P16', 'POS5', 'H1'], ['MOVER', 'ROB', 'POS5', 'POS13'], ['PICK', 'ROB', 'P13', 'POS13'], ['MOVER', 'ROB', 'POS13', 'POS3'], ['PLACE', 'ROB', 'P13', 'POS3', 'H1'], ['MOVER', 'ROB', 'POS3', 'POS11'], ['PICK', 'ROB', 'P11', 'POS11'], ['MOVER', 'ROB', 'POS11', 'POS12'], ['PLACE', 'ROB', 'P11', 'POS12', 'H2'], ['MOVER', 'ROB', 'POS12', 'POS10'], ['PICK', 'ROB', 'P10', 'POS10'], ['MOVER', 'ROB', 'POS10', 'POS12'], ['PLACE', 'ROB', 'P10', 'POS12', 'H3'], ['MOVER', 'ROB', 'POS12', 'POS9'], ['PICK', 'ROB', 'P9', 'POS9'], ['MOVER', 'ROB', 'POS9', 'POS5'], ['PLACE', 'ROB', 'P9', 'POS5', 'H2'], ['MOVER', 'ROB', 'POS5', 'POS8'], ['PICK', 'ROB', 'P8', 'POS8'], ['MOVER', 'ROB', 'POS8', 'POS5'], ['PLACE', 'ROB', 'P8', 'POS5', 'H3'], ['MOVER', 'ROB', 'POS5', 'POS7'], ['PICK', 'ROB', 'P7', 'POS7'], ['MOVER', 'ROB', 'POS7', 'POS3'], ['PLACE', 'ROB', 'P7', 'POS3', 'H2'], ['MOVER', 'ROB', 'POS3', 'POS6'], ['PICK', 'ROB', 'P6', 'POS6'], ['MOVER', 'ROB', 'POS6', 'POS3'], ['PLACE', 'ROB', 'P6', 'POS3', 'H3'], ['MOVER', 'ROB', 'POS3', 'POS1'], ['PICK', 'ROB', 'P1', 'POS1'], ['MOVER', 'ROB', 'POS1', 'POS14'], ['PLACE', 'ROB', 'P1', 'POS14', 'H1'], ['MOVER', 'ROB', 'POS14', 'POS4'], ['PICK', 'ROB', 'P4', 'POS4'], ['MOVER', 'ROB', 'POS4', 'POS14'], ['PLACE', 'ROB', 'P4', 'POS14', 'H2'], ['MOVER', 'ROB', 'POS14', 'POS2'], ['PICK', 'ROB', 'P2', 'POS2'], ['MOVER', 'ROB', 'POS2', 'POS14'], ['PLACE', 'ROB', 'P2', 'POS14', 'H3']]
